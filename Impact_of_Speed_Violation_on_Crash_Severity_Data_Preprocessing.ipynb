# %%
import pandas as P

# %%
D = P.read_csv("Nigeria Crash Data.csv")

# %%
print(D.columns)
# Out:
# Index(['Quarter', 'State', 'Total_Crashes', 'Num_Injured', 'Num_Killed',
#        'Total_Vehicles_Involved', 'SPV', 'DAD', 'PWR', 'FTQ', 'Other_Factors'],
#       dtype='object')

# %%
Missing_Values = D.isnull().sum()
print(Missing_Values)
# Out:
# Quarter                    0
# State                      0
# Total_Crashes              0
# Num_Injured                0
# Num_Killed                 0
# Total_Vehicles_Involved    0
# SPV                        0
# DAD                        0
# PWR                        0
# FTQ                        0
# Other_Factors              0
# dtype: int64

# %%
print(D.dtypes)
# Out:
# Quarter                    object
# State                      object
# Total_Crashes               int64
# Num_Injured                 int64
# Num_Killed                  int64
# Total_Vehicles_Involved     int64
# SPV                         int64
# DAD                         int64
# PWR                         int64
# FTQ                         int64
# Other_Factors               int64
# dtype: object

# %%
D["Quarter"] = P.to_numeric(D["Quarter"] , errors = "coerce")

# %%
D["State"] = P.to_numeric(D["State"] , errors = "coerce")

# %%
print(D.dtypes)
# Out:
# Quarter                    float64
# State                      float64
# Total_Crashes                int64
# Num_Injured                  int64
# Num_Killed                   int64
# Total_Vehicles_Involved      int64
# SPV                          int64
# DAD                          int64
# PWR                          int64
# FTQ                          int64
# Other_Factors                int64
# dtype: object

# %%
Drop_Duplicates = D.drop_duplicates()
print(Drop_Duplicates)
# Out:
#      Quarter  State  Total_Crashes  Num_Injured  Num_Killed  \
# 0        NaN    NaN             30          146          31
# 1        NaN    NaN             77          234          36
# 2        NaN    NaN             22           28           7
# 3        NaN    NaN             72          152          20
# 4        NaN    NaN            154          685          90
# ..       ...    ...            ...          ...         ...
# 513      NaN    NaN             15           32           4
# 514      NaN    NaN             24          122          41
# 515      NaN    NaN             38           98          17
# 516      NaN    NaN             39          234          13
# 517      NaN    NaN             13           61          14
#
#      Total_Vehicles_Involved  SPV  DAD  PWR  FTQ  Other_Factors
# 0                         37   19    0    0    0             18
# 1                         94   57    0    0    0             37
# 2                         24   15    0    0    1              8
# 3                         83   43    1    0    0             39
# 4                        140   74    0    0    0             66
# ..                       ...  ...  ...  ...  ...            ...
# 513                       21   17    0    0    0              4
# 514                       52   41    0    0    0             11
# 515                       38   17    0    0    0             21
# 516                       55   38    0    0    0             17
# 517                       16   14    0    0    0              2
#
# [518 rows x 11 columns]

# %%
Check_Negetive = (D < 0).any ()

# %%
print(Check_Negetive)
# Out:
# Quarter                    False
# State                      False
# Total_Crashes              False
# Num_Injured                False
# Num_Killed                 False
# Total_Vehicles_Involved    False
# SPV                        False
# DAD                        False
# PWR                        False
# FTQ                        False
# Other_Factors               True
# dtype: bool

# %%
D["Other_Factors"] = D["Other_Factors"].abs()

# %%
Q1 = D.quantile(0.25)
Q3 = D.quantile(0.75)
IQR = Q3 - Q1

# %%
Outlier = (D < (Q1 - 1.5 * IQR)) | (D > (Q3 + 1.5 * IQR))
print(Outlier)
print(Outlier.sum())
# Out:
#      Quarter  State  Total_Crashes  Num_Injured  Num_Killed  \
# 0      False  False          False        False       False
# 1      False  False          False        False       False
# 2      False  False          False        False       False
# 3      False  False          False        False       False
# 4      False  False          False         True       False
# ..       ...    ...            ...          ...         ...
# 513    False  False          False        False       False
# 514    False  False          False        False       False
# 515    False  False          False        False       False
# 516    False  False          False        False       False
# 517    False  False          False        False       False
#
#      Total_Vehicles_Involved    SPV    DAD    PWR    FTQ  Other_Factors
# 0                      False  False  False  False  False          False
# 1                      False  False  False  False  False          False
# 2                      False  False  False  False  False          False
# 3                      False  False   True  False  False          False
# 4                      False  False  False  False  False          False
# ..                       ...    ...    ...    ...    ...            ...
# 513                    False  False  False  False  False          False
# 514                    False  False  False  False  False          False
# 515                    False  False  False  False  False          False
# 516                    False  False  False  False  False          False
# 517                    False  False  False  False  False          False
#
# [518 rows x 11 columns]
# Quarter                     0
# State                       0
# Total_Crashes              33
# Num_Injured                22
# Num_Killed                 24
# Total_Vehicles_Involved    33
# SPV                        25
# DAD                        55
# PWR                        67
# FTQ                        81
# Other_Factors              31
# dtype: int64

# %%
A = Q1 - 1.5 * IQR
B = Q3 + 1.5 * IQR
D = D.clip(lower = A, upper = B, axis=1)

# %%
Columns_Drop = D["Other_Factors"]
Columns_Drop = D["Quarter"]
Columns_Drop = D["State"]

# %%
D.drop(columns = ["Other_Factors"] , inplace = True)
D.drop(columns = ["Quarter"] , inplace = True)
D.drop(columns = ["State"] , inplace = True)

# %%
Category = D.select_dtypes(include = "object").columns

# %%
print(Category)
# Out:
# Index([], dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
D.isnull().sum()


D = D.fillna(0)

# %%
D_scaled = D.copy()
D_scaled[C] = scaler.fit_transform(D_scaled[C])

# %%
print(D_scaled)
# Out:
#      Total_Crashes  Num_Injured  Num_Killed  Total_Vehicles_Involved  \
# 0        -0.789933    -0.508843   -0.251305                -0.692582
# 1        -0.023955    -0.033263   -0.091148                 0.019787
# 2        -0.920312    -1.146552   -1.020061                -0.855053
# 3        -0.105442    -0.476417   -0.603651                -0.117688
# 4         1.230946     2.400706    1.638553                 0.594682
# ..             ...          ...         ...                      ...
# 513      -1.034394    -1.124935   -1.116155                -0.892546
# 514      -0.887717    -0.638547    0.069010                -0.505117
# 515      -0.659553    -0.768250   -0.699746                -0.680085
# 516      -0.643256    -0.033263   -0.827872                -0.467624
# 517      -1.066989    -0.968210   -0.795840                -0.955034
#
#           SPV  DAD  PWR       FTQ
# 0   -0.346619  0.0  0.0 -0.671464
# 1    0.573584  0.0  0.0 -0.671464
# 2   -0.443482  0.0  0.0 -0.621067
# 3    0.234562  0.0  0.0 -0.671464
# 4    0.985254  0.0  0.0 -0.671464
# ..        ...  ...  ...       ...
# 513 -0.395051  0.0  0.0 -0.671464
# 514  0.186130  0.0  0.0 -0.671464
# 515 -0.395051  0.0  0.0 -0.671464
# 516  0.113483  0.0  0.0 -0.671464
# 517 -0.467698  0.0  0.0 -0.671464
#
# [518 rows x 8 columns]

# %%
X = D.drop(columns = ["Num_Killed"] , axis = 1)
Y = D["Num_Killed"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train , X_Test , Y_Train , Y_Test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %%
C_Final_Null = D.isnull().sum()
print(C_Final_Null)
# Out:
# Total_Crashes              0
# Num_Injured                0
# Num_Killed                 0
# Total_Vehicles_Involved    0
# SPV                        0
# DAD                        0
# PWR                        0
# FTQ                        0
# dtype: int64

# %%
Save_File = D.to_csv("Nigeria Crash Data (New).csv")
