# %% [markdown]
# Ignore Warning

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Loading Panda

# %%
import pandas as P

# %% [markdown]
# Opening Dataset

# %%
D = P.read_csv("Nigeria Crash Data U.csv")

# %% [markdown]
# Columns

# %%
print(D.columns)
# Out:
# Index(['Unnamed: 0', 'Quarter', 'State', 'Total_Crashes', 'Num_Injured',
#        'Num_Killed', 'Total_Vehicles_Involved', 'SPV', 'DAD', 'PWR', 'FTQ',
#        'Other_Factors'],
#       dtype='object')

# %% [markdown]
# X = Input , Y = Input

# %%
X = D.drop(["Num_Killed"] , axis = 1)
Y = D["Num_Killed"]

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train , X_Test , Y_Train , Y_Test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)

# %% [markdown]
# Printing

# %%
print(X_Train.shape)
print(X_Test.shape)
print(Y_Train.shape)
print(Y_Test.shape)
# Out:
# (414, 11)
# (104, 11)
# (414,)
# (104,)

# %% [markdown]
# Applying Model with not overfitting with not hyper parameter

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor(
    n_estimators=200,
    max_depth=8,
    min_samples_leaf=8,
    min_samples_split=10,
    max_features=0.6,
    random_state=42
)

# %%
RF.fit(X_Train , Y_Train)
# Out:
# RandomForestRegressor(max_depth=8, max_features=0.6, min_samples_leaf=8,
#                       min_samples_split=10, n_estimators=200, random_state=42)

# %% [markdown]
# Performance

# %%
import numpy as N
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error

# %%
R2 = r2_score(Y_Test , BM.predict(X_Test))
MSE = mean_squared_error(Y_Test , BM.predict(X_Test))
MAE = mean_absolute_error(Y_Test , BM.predict(X_Test))
RMSE = N.sqrt(MSE)

# %%
print(R2 * 100 , "%")
print("\n")
print(MSE)
print("\n")
print(MAE)
print("\n")
print(RMSE)
# Out:
# 74.71959086697441 %
#
#
# 276.23764946197747
#
#
# 12.383464721645254
#
#
# 16.62039859515943

# %%
Train_Score = BM.score(X_Train , Y_Train)
print(Train_Score * 100 , "%")
print("\n")
Test_Score = BM.score(X_Test , Y_Test)
print(Test_Score * 100 , "%")
# Out:
# 90.40168239361331 %
#
#
# 74.71959086697441 %
